# %% [markdown]
# <a href="https://colab.research.google.com/github/Ziyi-star/Bachelor-Project/blob/main/notebooks/handlebar/LSTM/Lstm__Handlebar_best.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# For Vscode
import numpy as np
import pandas as pd
from tensorflow import keras
from tensorflow.keras import layers
from datetime import datetime
from matplotlib import pyplot as plt
from matplotlib import dates as md
from sklearn.model_selection import train_test_split    #model selection and scaling data
from sklearn.preprocessing import StandardScaler
import tensorflow as tf #building model
RANDOM_SEED = 42

import sys
sys.path.append('../../../')   # Add parent directory to Python path
from utils.Plots import *

df = pd.read_csv('../../../data/handlebar/Accelerometer_data_combined_segmented_overlap_50.csv')
# 0 for normal, 1 for abnormal
df['curb_scene'].value_counts()
#df.drop('Unnamed: 0', axis=1, inplace=True)
df.head()
# Out:
#    curb_scene               start_time                 end_time   Acc-Z_1  \
# 0         0.0  2024-07-24 10:26:01.863  2024-07-24 10:26:02.355  8.762772
# 1         0.0  2024-07-24 10:26:02.111  2024-07-24 10:26:02.602  8.762772
# 2         0.0  2024-07-24 10:26:02.359  2024-07-24 10:26:02.851  8.781937
# 3         0.0  2024-07-24 10:26:02.608  2024-07-24 10:26:03.099  8.781937
# 4         0.0  2024-07-24 10:26:02.856  2024-07-24 10:26:03.348  8.757996
#
#     Acc-Z_2   Acc-Z_3   Acc-Z_4   Acc-Z_5   Acc-Z_6   Acc-Z_7  ...  Acc-Z_91  \
# 0  8.753204  8.762772  8.781937  8.753204  8.748413  8.738831  ...  8.786728
# 1  8.762772  8.748413  8.767563  8.729263  8.695740  8.724472  ...  8.753204
# 2  8.796295  8.772354  8.772354  8.772354  8.786728  8.781937  ...  8.777145
# 3  8.753204  8.801086  8.753204  8.829819  8.753204  8.786728  ...  8.805878
# 4  8.762772  8.777145  8.767563  8.786728  8.777145  8.753204  ...  8.757996
#
#    Acc-Z_92  Acc-Z_93  Acc-Z_94  Acc-Z_95  Acc-Z_96  Acc-Z_97  Acc-Z_98  \
# 0  8.801086  8.820236  8.786728  8.777145  8.772354  8.781937  8.801086
# 1  8.772354  8.786728  8.781937  8.786728  8.777145  8.738831  8.820236
# 2  8.753204  8.767563  8.762772  8.762772  8.753204  8.748413  8.762772
# 3  8.796295  8.781937  8.801086  8.810669  8.796295  8.805878  8.791504
# 4  8.757996  8.772354  8.767563  8.757996  8.743622  8.777145  8.743622
#
#    Acc-Z_99  Acc-Z_100
# 0  8.781937   8.753204
# 1  8.738831   8.757996
# 2  8.772354   8.767563
# 3  8.791504   8.772354
# 4  8.786728   8.796295
#
# [5 rows x 103 columns]

# %%
# For Colab
import numpy as np
import pandas as pd
from tensorflow import keras
from tensorflow.keras import layers
from datetime import datetime
from matplotlib import pyplot as plt
from matplotlib import dates as md
from sklearn.model_selection import train_test_split    #model selection and scaling data
from sklearn.preprocessing import StandardScaler
import tensorflow as tf #building model
RANDOM_SEED = 42


import os
from google.colab import drive
drive.mount('/content/drive')
df = pd.read_csv('/content/drive/MyDrive/Project/data/Accelerometer_data_combined_segmented_overlap_50.csv')
# # 0 for normal, 1 for abnormal
df['curb_scene'].value_counts()
df.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#    Unnamed: 0  curb_scene   Acc-Z_1   Acc-Z_2   Acc-Z_3   Acc-Z_4   Acc-Z_5  \
# 0           0         0.0  8.762772  8.753204  8.762772  8.781937  8.753204
# 1           0         0.0  8.762772  8.762772  8.748413  8.767563  8.729263
# 2           0         0.0  8.781937  8.796295  8.772354  8.772354  8.772354
# 3           0         0.0  8.781937  8.753204  8.801086  8.753204  8.829819
# 4           0         0.0  8.757996  8.762772  8.777145  8.767563  8.786728
#
#     Acc-Z_6   Acc-Z_7   Acc-Z_8  ...  Acc-Z_91  Acc-Z_92  Acc-Z_93  Acc-Z_94  \
# 0  8.748413  8.738831  8.748413  ...  8.786728  8.801086  8.820236  8.786728
# 1  8.695740  8.724472  8.767563  ...  8.753204  8.772354  8.786728  8.781937
# 2  8.786728  8.781937  8.801086  ...  8.777145  8.753204  8.767563  8.762772
# 3  8.753204  8.786728  8.815445  ...  8.805878  8.796295  8.781937  8.801086
# 4  8.777145  8.753204  8.757996  ...  8.757996  8.757996  8.772354  8.767563
#
#    Acc-Z_95  Acc-Z_96  Acc-Z_97  Acc-Z_98  Acc-Z_99  Acc-Z_100
# 0  8.777145  8.772354  8.781937  8.801086  8.781937   8.753204
# 1  8.786728  8.777145  8.738831  8.820236  8.738831   8.757996
# 2  8.762772  8.753204  8.748413  8.762772  8.772354   8.767563
# 3  8.810669  8.796295  8.805878  8.791504  8.791504   8.772354
# 4  8.757996  8.743622  8.777145  8.743622  8.786728   8.796295
#
# [5 rows x 102 columns]

# %%
#df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
# Suppose df is your DataFrame, and df['curb_scene'] is your label column
train_data, test_data, train_labels, test_labels = train_test_split(df, df['curb_scene'],
                                                                    test_size=0.2,
                                                                    random_state=RANDOM_SEED)

# %%
#scaling data, because neural network works better with scaled data
scaler = StandardScaler()
data_scaled = scaler.fit(train_data.iloc[:, 3:])
#transform data
train_data_scaled = scaler.transform(train_data.iloc[:, 3:])
test_data_scaled = scaler.transform(test_data.iloc[:, 3:])
train_data_scaled.shape
# Out:
# (2984, 100)

# %%
# Convert the scaled data back to DataFrames for further processing
# takes all column names from the original DataFrame starting from index 3
train_data_scaled_df = pd.DataFrame(train_data_scaled, columns=train_data.columns[3:])
test_data_scaled_df = pd.DataFrame(test_data_scaled, columns=test_data.columns[3:])
# Add the 'curb_scene', 'start_time', and 'end_time' columns back to the scaled DataFrames
train_data_scaled_df['curb_scene'] = train_data['curb_scene'].values
test_data_scaled_df['curb_scene'] = test_data['curb_scene'].values
train_data_scaled_df.head()
# Out:
#     Acc-Z_1   Acc-Z_2   Acc-Z_3   Acc-Z_4   Acc-Z_5   Acc-Z_6   Acc-Z_7  \
# 0 -0.043399 -0.036445 -0.039909 -0.060094 -0.050310 -0.047696 -0.075391
# 1  1.732833  0.861269 -0.066900 -1.345973 -0.894126  0.209820  0.934705
# 2  1.108598 -0.307952 -1.216212 -1.146256  0.185394  1.187373  0.592034
# 3 -0.553325 -0.653575 -1.007376 -1.028728 -0.073208  0.570197  0.683861
# 4  0.970780  1.017063  0.127729 -0.398848 -0.465148 -0.729610 -1.568511
#
#     Acc-Z_8   Acc-Z_9  Acc-Z_10  ...  Acc-Z_92  Acc-Z_93  Acc-Z_94  Acc-Z_95  \
# 0 -0.089531 -0.090752 -0.076505  ... -0.043150 -0.071323 -0.096998 -0.097019
# 1  0.829993 -0.302878 -0.544242  ...  0.655119 -0.304608 -0.794407 -1.651467
# 2 -1.013123 -0.958307  0.582645  ... -0.685252 -0.784423  0.974519  1.458073
# 3  0.283433 -0.743554  0.084684  ...  0.607887 -0.015207 -0.946822 -0.043461
# 4 -1.432877 -0.073019  0.897828  ... -0.536533  0.011905 -0.465826 -0.511925
#
#    Acc-Z_96  Acc-Z_97  Acc-Z_98  Acc-Z_99  Acc-Z_100  curb_scene
# 0 -0.058825 -0.062461 -0.066930 -0.065874  -0.066939         0.0
# 1 -1.752088 -0.370351 -0.366041  1.040036   1.820544         1.0
# 2  0.009070 -1.326325 -0.443189  0.728941   1.383342         0.0
# 3 -0.298542 -0.262453 -0.822154 -0.065264   0.862935         0.0
# 4 -0.461355 -0.283758 -0.314610  0.056735  -0.128249         0.0
#
# [5 rows x 101 columns]

# %%
# Filter and slice the data
normal_train_data_scaled = train_data_scaled_df[train_data_scaled_df['curb_scene'] == 0.0].iloc[:, :-1]
abnormal_train_data_scaled = train_data_scaled_df[train_data_scaled_df['curb_scene'] == 1.0].iloc[:, :-1]
normal_test_data_scaled = test_data_scaled_df[test_data_scaled_df['curb_scene'] == 0.0].iloc[:, :-1]
abnormal_test_data_scaled = test_data_scaled_df[test_data_scaled_df['curb_scene'] == 1.0].iloc[:, :-1]

# %%
# Cast to float32
normal_train_data_scaled = normal_train_data_scaled.astype("float32")
abnormal_train_data_scaled = abnormal_train_data_scaled.astype("float32")
normal_test_data_scaled = normal_test_data_scaled.astype("float32")
abnormal_test_data_scaled = abnormal_test_data_scaled.astype("float32")

# %%
# Reshape the data for LSTM input((samples, timesteps, features))
normal_train_data_scaled_lstm = np.expand_dims(normal_train_data_scaled, axis=1)
normal_test_data_scaled_lstm = np.expand_dims(normal_test_data_scaled, axis=1)
abnormal_test_data_scaled_lstm = np.expand_dims(abnormal_test_data_scaled, axis=1)
normal_train_data_scaled_lstm.shape, normal_test_data_scaled_lstm.shape, abnormal_test_data_scaled_lstm.shape
# Out:
# ((2830, 1, 100), (711, 1, 100), (35, 1, 100))

# %%
from keras.models import Sequential
from keras.layers import LSTM, Input, Dropout
from keras.layers import Dense
from keras.layers import RepeatVector
from keras.layers import TimeDistributed
from keras.models import Model

model = Sequential()
# Encoder
model.add(Input(shape=(normal_train_data_scaled_lstm.shape[1], normal_train_data_scaled_lstm.shape[2])))
model.add(LSTM(224, activation='tanh', return_sequences=True))
model.add(LSTM(128, activation='tanh', return_sequences=True))

#decoder
model.add(LSTM(128, activation='tanh', return_sequences=True))
model.add(LSTM(224, activation='tanh', return_sequences=True))
model.add(TimeDistributed(Dense(normal_train_data_scaled_lstm.shape[2])))
model.compile(optimizer='adam', loss='mae')
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_4 (LSTM)                   │ (None, 1, 224)         │       291,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_5 (LSTM)                   │ (None, 1, 128)         │       180,736 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_6 (LSTM)                   │ (None, 1, 128)         │       131,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_7 (LSTM)                   │ (None, 1, 224)         │       316,288 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_1              │ (None, 1, 100)         │        22,500 │
# │ (TimeDistributed)               │                        │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 942,308 (3.59 MB)
#  Trainable params: 942,308 (3.59 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# define early stopping to prevent overfit
early_stopping = keras.callbacks.EarlyStopping(monitor="val_loss",
                                               patience=10,
                                               mode="min",
                                               verbose=1,
                                               restore_best_weights=True)

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001)
model.compile(optimizer=optimizer, loss='mae')

# %%
# fit model
history = model.fit(
    normal_train_data_scaled_lstm, normal_train_data_scaled_lstm,
    epochs=200,
    batch_size=160,
    validation_split=0.3,
    callbacks=[early_stopping],
    shuffle=True,
    verbose=1)
# Out:
# Epoch 1/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 57ms/step - loss: 0.4368 - val_loss: 0.4364
# Epoch 2/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.4318 - val_loss: 0.4362
# Epoch 3/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.4328 - val_loss: 0.4359
# Epoch 4/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.4415 - val_loss: 0.4357
# Epoch 5/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.4370 - val_loss: 0.4354
# Epoch 6/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.4329 - val_loss: 0.4351
# Epoch 7/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.4342 - val_loss: 0.4347
# Epoch 8/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.4328 - val_loss: 0.4341
# Epoch 9/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.4308 - val_loss: 0.4333
# Epoch 10/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.4341 - val_loss: 0.4321
# Epoch 11/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.4365 - val_loss: 0.4299
# Epoch 12/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.4214 - val_loss: 0.4263
# Epoch 13/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.4315 - val_loss: 0.4208
# Epoch 14/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.4181 - val_loss: 0.4148
# Epoch 15/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.4194 - val_loss: 0.4106
# Epoch 16/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.4102 - val_loss: 0.4078
# Epoch 17/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.4053 - val_loss: 0.4041
# Epoch 18/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.4051 - val_loss: 0.3997
# Epoch 19/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.3921 - val_loss: 0.3947
# Epoch 20/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.3906 - val_loss: 0.3906
# Epoch 21/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.3894 - val_loss: 0.3883
# Epoch 22/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.3878 - val_loss: 0.3872
# Epoch 23/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.3873 - val_loss: 0.3865
# Epoch 24/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.3815 - val_loss: 0.3860
# Epoch 25/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.3812 - val_loss: 0.3856
# Epoch 26/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.3843 - val_loss: 0.3853
# Epoch 27/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.3875 - val_loss: 0.3849
# Epoch 28/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.3840 - val_loss: 0.3846
# Epoch 29/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.3862 - val_loss: 0.3844
# Epoch 30/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.3866 - val_loss: 0.3841
# Epoch 31/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.3821 - val_loss: 0.3839
# Epoch 32/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.3812 - val_loss: 0.3837
# Epoch 33/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.3801 - val_loss: 0.3835
# Epoch 34/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.
# Epoch 130/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.3138 - val_loss: 0.3196
# Epoch 131/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.3122 - val_loss: 0.3194
# Epoch 132/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.3116 - val_loss: 0.3193
# Epoch 133/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.3127 - val_loss: 0.3191
# Epoch 134/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.3098 - val_loss: 0.3190
# Epoch 135/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.3112 - val_loss: 0.3188
# Epoch 136/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.3166 - val_loss: 0.3187
# Epoch 137/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.3106 - val_loss: 0.3185
# Epoch 138/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.3143 - val_loss: 0.3184
# Epoch 139/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.3139 - val_loss: 0.3182
# Epoch 140/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.3122 - val_loss: 0.3180
# Epoch 141/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.3157 - val_loss: 0.3177
# Epoch 142/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.3134 - val_loss: 0.3175
# Epoch 143/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.3190 - val_loss: 0.3172
# Epoch 144/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.3049 - val_loss: 0.3169
# Epoch 145/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.3095 - val_loss: 0.3166
# Epoch 146/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.3120 - val_loss: 0.3162
# Epoch 147/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.3091 - val_loss: 0.3157
# Epoch 148/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.3160 - val_loss: 0.3152
# Epoch 149/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.3059 - val_loss: 0.3147
# Epoch 150/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.3089 - val_loss: 0.3142
# Epoch 151/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.3115 - val_loss: 0.3136
# Epoch 152/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.3032 - val_loss: 0.3132
# Epoch 153/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.3092 - val_loss: 0.3128
# Epoch 154/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.3064 - val_loss: 0.3124
# Epoch 155/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2987 - val_loss: 0.3121
# Epoch 156/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.3067 - val_loss: 0.3119
# Epoch 157/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.3056 - val_loss: 0.3118
# Epoch 158/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.3059 - val_loss: 0.3116
# Epoch 159/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.3044 - val_loss: 0.3115
# Epoch 160/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.2999 - val_loss: 0.3114
# Epoch 161/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.3040 - val_loss: 0.3113
# Epoch 162/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.3060 - val_loss: 0.3112
# Epoch 163/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.2975 - val_loss: 0.3111
# Epoch 164/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.3012 - val_loss: 0.3111
# Epoch 165/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.3040 - val_loss: 0.3110
# Epoch 166/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.2996 - val_loss: 0.3109
# Epoch 167/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.3066 - val_loss: 0.3108
# Epoch 168/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.3038 - val_loss: 0.3107
# Epoch 169/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.3053 - val_loss: 0.3106
# Epoch 170/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.3020 - val_loss: 0.3105
# Epoch 171/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.3027 - val_loss: 0.3104
# Epoch 172/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2997 - val_loss: 0.3103
# Epoch 173/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2983 - val_loss: 0.3102
# Epoch 174/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.3055 - val_loss: 0.3101
# Epoch 175/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.2950 - val_loss: 0.3099
# Epoch 176/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2985 - val_loss: 0.3097
# Epoch 177/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.3004 - val_loss: 0.3096
# Epoch 178/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.3010 - val_loss: 0.3093
# Epoch 179/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.3063 - val_loss: 0.3091
# Epoch 180/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.3028 - val_loss: 0.3087
# Epoch 181/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.3023 - val_loss: 0.3084
# Epoch 182/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.3007 - val_loss: 0.3081
# Epoch 183/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.2986 - val_loss: 0.3076
# Epoch 184/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2991 - val_loss: 0.3071
# Epoch 185/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2997 - val_loss: 0.3066
# Epoch 186/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.3006 - val_loss: 0.3060
# Epoch 187/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.2999 - val_loss: 0.3054
# Epoch 188/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.2929 - val_loss: 0.3048
# Epoch 189/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.2960 - val_loss: 0.3043
# Epoch 190/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.2955 - val_loss: 0.3038
# Epoch 191/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2975 - val_loss: 0.3034
# Epoch 192/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.2946 - val_loss: 0.3030
# Epoch 193/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.2924 - val_loss: 0.3026
# Epoch 194/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2966 - val_loss: 0.3023
# Epoch 195/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.2996 - val_loss: 0.3021
# Epoch 196/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.2935 - val_loss: 0.3017
# Epoch 197/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.2937 - val_loss: 0.3015
# Epoch 198/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.2932 - val_loss: 0.3012
# Epoch 199/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2914 - val_loss: 0.3009
# Epoch 200/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.2900 - val_loss: 0.3006
# Restoring model weights from the end of the best epoch: 200.

# %%
plt.plot(history.history['loss'], label='Training loss')
plt.plot(history.history['val_loss'], label='Validation loss')
plt.legend()

# %%
load_model = tf.keras.models.load_model('../../../models/lstm_autoencoder_handlebar_best.keras')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 load_model = tf.keras.models.load_model('../../../models/lstm_autoencoder_handlebar_best.keras')
#
# File c:\Users\liuzi\miniconda3\Lib\site-packages\keras\src\saving\saving_api.py:200, in load_model(filepath, custom_objects, compile, safe_mode)
#     196     return legacy_h5_format.load_model_from_hdf5(
#     197         filepath, custom_objects=custom_objects, compile=compile
#     198     )
#     199 elif str(filepath).endswith(".keras"):
# --> 200     raise ValueError(
#     201         f"File not found: filepath={filepath}. "
#     202         "Please ensure the file is an accessible `.keras` "
#     203         "zip file."
#     204     )
#     205 else:
#     206     raise ValueError(
#     207         f"File format not supported: filepath={filepath}. "
#     208         "Keras 3 only supports V3 `.keras` files and "
#    (...)
#     217         "might have a different name)."
#     218     )
#
# ValueError: File not found: filepath=../../../models/lstm_autoencoder_handlebar_best.keras. Please ensure the file is an accessible `.keras` zip file.
