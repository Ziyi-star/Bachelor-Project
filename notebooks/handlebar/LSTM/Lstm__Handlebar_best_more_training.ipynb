# %% [markdown]
# <a href="https://colab.research.google.com/github/Ziyi-star/Bachelor-Project/blob/main/notebooks/handlebar/LSTM/Lstm__Handlebar_best.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# For Vscode
import numpy as np
import pandas as pd
from tensorflow import keras
from tensorflow.keras import layers
from datetime import datetime
from matplotlib import pyplot as plt
from matplotlib import dates as md
from sklearn.model_selection import train_test_split    #model selection and scaling data
from sklearn.preprocessing import StandardScaler
import tensorflow as tf #building model
RANDOM_SEED = 42

import sys
sys.path.append('../../../')   # Add parent directory to Python path
from utils.Plots import *

df = pd.read_csv('../../../data/handlebar/processed_segments_overlap_50_more.csv')
# 0 for normal, 1 for abnormal
df['curb_scene'].value_counts()
df.drop('Unnamed: 0', axis=1, inplace=True)
print(df.shape)
df.head()
# Out:
# (9317, 101)
#    curb_scene   Acc-Z_1   Acc-Z_2   Acc-Z_3   Acc-Z_4   Acc-Z_5   Acc-Z_6  \
# 0         0.0  8.762772  8.753204  8.762772  8.781937  8.753204  8.748413
# 1         0.0  8.762772  8.762772  8.748413  8.767563  8.729263  8.695740
# 2         0.0  8.781937  8.796295  8.772354  8.772354  8.772354  8.786728
# 3         0.0  8.781937  8.753204  8.801086  8.753204  8.829819  8.753204
# 4         0.0  8.757996  8.762772  8.777145  8.767563  8.786728  8.777145
#
#     Acc-Z_7   Acc-Z_8   Acc-Z_9  ...  Acc-Z_91  Acc-Z_92  Acc-Z_93  Acc-Z_94  \
# 0  8.738831  8.748413  8.743622  ...  8.786728  8.801086  8.820236  8.786728
# 1  8.724472  8.767563  8.767563  ...  8.753204  8.772354  8.786728  8.781937
# 2  8.781937  8.801086  8.767563  ...  8.777145  8.753204  8.767563  8.762772
# 3  8.786728  8.815445  8.762772  ...  8.805878  8.796295  8.781937  8.801086
# 4  8.753204  8.757996  8.777145  ...  8.757996  8.757996  8.772354  8.767563
#
#    Acc-Z_95  Acc-Z_96  Acc-Z_97  Acc-Z_98  Acc-Z_99  Acc-Z_100
# 0  8.777145  8.772354  8.781937  8.801086  8.781937   8.753204
# 1  8.786728  8.777145  8.738831  8.820236  8.738831   8.757996
# 2  8.762772  8.753204  8.748413  8.762772  8.772354   8.767563
# 3  8.810669  8.796295  8.805878  8.791504  8.791504   8.772354
# 4  8.757996  8.743622  8.777145  8.743622  8.786728   8.796295
#
# [5 rows x 101 columns]

# %%
# For Colab
import numpy as np
import pandas as pd
from tensorflow import keras
from tensorflow.keras import layers
from datetime import datetime
from matplotlib import pyplot as plt
from matplotlib import dates as md
from sklearn.model_selection import train_test_split    #model selection and scaling data
from sklearn.preprocessing import StandardScaler
import tensorflow as tf #building model
RANDOM_SEED = 42


import os
from google.colab import drive
drive.mount('/content/drive')
df = pd.read_csv('/content/drive/MyDrive/Project/data/processed_segments_overlap_50_more.csv')
# # 0 for normal, 1 for abnormal
df['curb_scene'].value_counts()
df.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#    Unnamed: 0  curb_scene   Acc-Z_1   Acc-Z_2   Acc-Z_3   Acc-Z_4   Acc-Z_5  \
# 0           0         0.0  8.762772  8.753204  8.762772  8.781937  8.753204
# 1           0         0.0  8.762772  8.762772  8.748413  8.767563  8.729263
# 2           0         0.0  8.781937  8.796295  8.772354  8.772354  8.772354
# 3           0         0.0  8.781937  8.753204  8.801086  8.753204  8.829819
# 4           0         0.0  8.757996  8.762772  8.777145  8.767563  8.786728
#
#     Acc-Z_6   Acc-Z_7   Acc-Z_8  ...  Acc-Z_91  Acc-Z_92  Acc-Z_93  Acc-Z_94  \
# 0  8.748413  8.738831  8.748413  ...  8.786728  8.801086  8.820236  8.786728
# 1  8.695740  8.724472  8.767563  ...  8.753204  8.772354  8.786728  8.781937
# 2  8.786728  8.781937  8.801086  ...  8.777145  8.753204  8.767563  8.762772
# 3  8.753204  8.786728  8.815445  ...  8.805878  8.796295  8.781937  8.801086
# 4  8.777145  8.753204  8.757996  ...  8.757996  8.757996  8.772354  8.767563
#
#    Acc-Z_95  Acc-Z_96  Acc-Z_97  Acc-Z_98  Acc-Z_99  Acc-Z_100
# 0  8.777145  8.772354  8.781937  8.801086  8.781937   8.753204
# 1  8.786728  8.777145  8.738831  8.820236  8.738831   8.757996
# 2  8.762772  8.753204  8.748413  8.762772  8.772354   8.767563
# 3  8.810669  8.796295  8.805878  8.791504  8.791504   8.772354
# 4  8.757996  8.743622  8.777145  8.743622  8.786728   8.796295
#
# [5 rows x 102 columns]

# %%
#df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
# Suppose df is your DataFrame, and df['curb_scene'] is your label column
train_data, test_data, train_labels, test_labels = train_test_split(df, df['curb_scene'],
                                                                    test_size=0.2,
                                                                    random_state=RANDOM_SEED)

# %%
#scaling data, because neural network works better with scaled data
scaler = StandardScaler()
data_scaled = scaler.fit(train_data.iloc[:, 1:])
#transform data
train_data_scaled = scaler.transform(train_data.iloc[:, 1:])
test_data_scaled = scaler.transform(test_data.iloc[:, 1:])
train_data_scaled.shape
# Out:
# (7453, 100)

# %%
# Convert the scaled data back to DataFrames for further processing
# takes all column names from the original DataFrame starting from index 1
train_data_scaled_df = pd.DataFrame(train_data_scaled, columns=train_data.columns[1:])
test_data_scaled_df = pd.DataFrame(test_data_scaled, columns=test_data.columns[1:])
# Add the 'curb_scene', 'start_time', and 'end_time' columns back to the scaled DataFrames
train_data_scaled_df['curb_scene'] = train_data['curb_scene'].values
test_data_scaled_df['curb_scene'] = test_data['curb_scene'].values
train_data_scaled_df.head()
# Out:
#     Acc-Z_1   Acc-Z_2   Acc-Z_3   Acc-Z_4   Acc-Z_5   Acc-Z_6   Acc-Z_7  \
# 0  0.099842  0.367573 -0.760735 -0.741110 -0.643996  1.478013  1.460586
# 1  0.287473 -0.438213 -0.262225 -0.632199  0.733360  0.425447  0.325230
# 2 -0.889006 -0.240796  0.149586  0.175351 -0.117633 -0.764769 -1.020560
# 3  1.466225  1.286168 -0.577708 -1.422806 -0.696546  0.911753  0.885006
# 4 -0.690028 -0.464805  1.045457  0.830425  0.002728 -1.053255 -0.338514
#
#     Acc-Z_8   Acc-Z_9  Acc-Z_10  ...  Acc-Z_92  Acc-Z_93  Acc-Z_94  Acc-Z_95  \
# 0  0.377973 -1.298170 -2.613329  ... -0.582613 -1.255213 -0.701392  0.471675
# 1  0.411709 -0.423649  0.776224  ... -0.527615  0.937265  1.770801  1.560933
# 2 -0.874950 -0.199176  0.381914  ... -0.216459 -0.520273 -0.635812 -0.342957
# 3 -0.045683 -1.041988 -0.455054  ... -3.053017  1.231087  2.014817 -2.399102
# 4  0.800059  0.798846  0.158502  ... -0.794318 -1.508160 -1.290846  0.791125
#
#    Acc-Z_96  Acc-Z_97  Acc-Z_98  Acc-Z_99  Acc-Z_100  curb_scene
# 0  0.901263  0.321502 -0.614684  0.125772   0.418495         0.0
# 1 -0.131658 -1.879847 -1.206281 -0.206123   0.528233         0.0
# 2  0.028676  1.100680  0.824921 -0.265390  -0.858003         0.0
# 3 -6.967440 -6.682476 -0.651555  0.426846  -4.315520         0.0
# 4  2.443709  1.781598 -0.239281 -0.758489  -0.189899         0.0
#
# [5 rows x 101 columns]

# %%
# Filter and slice the data
normal_train_data_scaled = train_data_scaled_df[train_data_scaled_df['curb_scene'] == 0.0].iloc[:, :-1]
abnormal_train_data_scaled = train_data_scaled_df[train_data_scaled_df['curb_scene'] == 1.0].iloc[:, :-1]
normal_test_data_scaled = test_data_scaled_df[test_data_scaled_df['curb_scene'] == 0.0].iloc[:, :-1]
abnormal_test_data_scaled = test_data_scaled_df[test_data_scaled_df['curb_scene'] == 1.0].iloc[:, :-1]

# %%
# Cast to float32
normal_train_data_scaled = normal_train_data_scaled.astype("float32")
abnormal_train_data_scaled = abnormal_train_data_scaled.astype("float32")
normal_test_data_scaled = normal_test_data_scaled.astype("float32")
abnormal_test_data_scaled = abnormal_test_data_scaled.astype("float32")

# %%
# Reshape the data for LSTM input((samples, timesteps, features))
normal_train_data_scaled_lstm = np.expand_dims(normal_train_data_scaled, axis=1)
abnormal_train_data_scaled_lstm = np.expand_dims(abnormal_train_data_scaled, axis=1)
normal_test_data_scaled_lstm = np.expand_dims(normal_test_data_scaled, axis=1)
abnormal_test_data_scaled_lstm = np.expand_dims(abnormal_test_data_scaled, axis=1)
normal_train_data_scaled_lstm.shape, abnormal_train_data_scaled_lstm.shape, normal_test_data_scaled_lstm.shape, abnormal_test_data_scaled_lstm.shape
# Out:
# ((7178, 1, 100), (275, 1, 100), (1796, 1, 100), (68, 1, 100))

# %%
from keras.models import Sequential
from keras.layers import LSTM, Input, Dropout
from keras.layers import Dense
from keras.layers import RepeatVector
from keras.layers import TimeDistributed
from keras.models import Model

model = Sequential()
# Encoder
model.add(Input(shape=(normal_train_data_scaled_lstm.shape[1], normal_train_data_scaled_lstm.shape[2])))
model.add(LSTM(224, activation='tanh', return_sequences=True))
model.add(LSTM(224, activation='tanh', return_sequences=True))

#decoder
model.add(LSTM(224, activation='tanh', return_sequences=True))
model.add(LSTM(224, activation='tanh', return_sequences=True))
model.add(TimeDistributed(Dense(normal_train_data_scaled_lstm.shape[2])))
model.compile(optimizer='adam', loss='mae')
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 1, 224)         │       291,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 1, 224)         │       402,304 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 1, 224)         │       402,304 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_3 (LSTM)                   │ (None, 1, 224)         │       402,304 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed                │ (None, 1, 100)         │        22,500 │
# │ (TimeDistributed)               │                        │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,520,612 (5.80 MB)
#  Trainable params: 1,520,612 (5.80 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
def draw_lstm_architecture():
    # Create figure and axis
    fig, ax = plt.subplots(figsize=(15, 8))
    
    # Define positions
    x_positions = [0, 2, 4, 6, 8, 10, 12]
    y_center = 5
    
    # Colors
    encoder_color = '#2ecc71'  # Green
    decoder_color = '#3498db'  # Blue
    bottleneck_color = '#e74c3c'  # Red
    io_color = '#95a5a6'  # Gray for input/output layers

    # Draw layers
    def draw_layer(x, text, color, is_io=False):
        if is_io:  # Changed is_input to is_io for both input and output
            width, height = 1, 3  # Smaller height for input/output
        else:
            width, height = 1, 5
        rect = plt.Rectangle((x - width/2, y_center - height/2), width, height,
                           facecolor=color, alpha=0.3, edgecolor=color)
        ax.add_patch(rect)
        plt.text(x, y_center + 2, text, ha='center', fontsize=10)
    
    # Input layer
    draw_layer(x_positions[0], f'Input\n(1, {normal_train_data_scaled_lstm.shape[2]})', io_color, is_io=True)
    
    # Encoder layers
    draw_layer(x_positions[1], 'LSTM\n(224)', encoder_color)
    draw_layer(x_positions[2], 'LSTM\n(224)', encoder_color)
    
    # Bottleneck layer
    draw_layer(x_positions[3], 'LSTM\n(224)', bottleneck_color)
    
    # Decoder layers
    draw_layer(x_positions[4], 'LSTM\n(224)', decoder_color)
    draw_layer(x_positions[5], 'LSTM\n(224)', decoder_color)
    
    # Output layer - now matches input layer style
    draw_layer(x_positions[6], f'Dense\n({normal_train_data_scaled_lstm.shape[2]})', io_color, is_io=True)
    
    # Add arrows
    for i in range(len(x_positions)-1):
        plt.arrow(x_positions[i] + 0.6, y_center, 
                 x_positions[i+1] - x_positions[i] - 1.2, 0,
                 head_width=0.2, head_length=0.2, fc='k', ec='k')
    
    # Customize plot
    #plt.title('LSTM Autoencoder Architecture', pad=20, fontsize=14)
    plt.text(x_positions[1], y_center - 3, 'Encoder', ha='center', fontsize=12, color=encoder_color)
    plt.text(x_positions[3], y_center - 3, 'Repeat Vector', ha='center', fontsize=12, color=bottleneck_color)
    plt.text(x_positions[4], y_center - 3, 'Decoder', ha='center', fontsize=12, color=decoder_color)
    
    # Set limits and remove axes
    plt.xlim(-1, 13)
    plt.ylim(0, 10)
    ax.axis('off')
    
    plt.tight_layout()
    plt.show()

# Call the function to create the visualization
draw_lstm_architecture()

# %%
# define early stopping to prevent overfit
early_stopping = keras.callbacks.EarlyStopping(monitor="val_loss",
                                               patience=10,
                                               mode="min",
                                               verbose=1,
                                               restore_best_weights=True)

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=0.00044)
model.compile(optimizer=optimizer, loss='mae')

# %%
# fit model
history = model.fit(
    normal_train_data_scaled_lstm, normal_train_data_scaled_lstm,
    epochs=200,
    batch_size=128,
    validation_split=0.3,
    callbacks=[early_stopping],
    shuffle=True,
    verbose=1)
# Out:
# Epoch 1/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - loss: 0.4623 - val_loss: 0.4506
# Epoch 2/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.4592 - val_loss: 0.4127
# Epoch 3/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.4180 - val_loss: 0.4021
# Epoch 4/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.4053 - val_loss: 0.3901
# Epoch 5/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.3984 - val_loss: 0.3770
# Epoch 6/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.3843 - val_loss: 0.3700
# Epoch 7/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.3752 - val_loss: 0.3680
# Epoch 8/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.3686 - val_loss: 0.3624
# Epoch 9/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.3652 - val_loss: 0.3488
# Epoch 10/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.3522 - val_loss: 0.3465
# Epoch 11/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.3524 - val_loss: 0.3454
# Epoch 12/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.3452 - val_loss: 0.3436
# Epoch 13/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.3473 - val_loss: 0.3382
# Epoch 14/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.3376 - val_loss: 0.3331
# Epoch 15/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.3315 - val_loss: 0.3298
# Epoch 16/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.3366 - val_loss: 0.3263
# Epoch 17/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.3263 - val_loss: 0.3231
# Epoch 18/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.3214 - val_loss: 0.3183
# Epoch 19/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.3178 - val_loss: 0.3134
# Epoch 20/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.3091 - val_loss: 0.3080
# Epoch 21/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.3082 - val_loss: 0.3039
# Epoch 22/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.3042 - val_loss: 0.3000
# Epoch 23/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2951 - val_loss: 0.2944
# Epoch 24/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.2909 - val_loss: 0.2899
# Epoch 25/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.2795 - val_loss: 0.2840
# Epoch 26/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.2770 - val_loss: 0.2792
# Epoch 27/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.2713 - val_loss: 0.2729
# Epoch 28/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.2694 - val_loss: 0.2665
# Epoch 29/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.2554 - val_loss: 0.2600
# Epoch 30/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2565 - val_loss: 0.2519
# Epoch 31/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.2405 - val_loss: 0.2450
# Epoch 32/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.2356 - val_loss: 0.2387
# Epoch 33/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2264 - val_loss: 0.2339
# Epoch 34/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.2261 - val_loss: 0.2287
# Epoch 35/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.2180 - val_loss: 0.2232
# Epoch 36/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.2111 - val_loss: 0.2179
# Epoch 37/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.2059 - val_loss: 0.2136
# Epoch 38/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.2012 - val_loss: 0.2086
# Epoch 39/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.1971 - val_loss: 0.2050
# Epoch 40/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1926 - val_loss: 0.2013
# Epoch 41/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1904 - val_loss: 0.1977
# Epoch 42/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1854 - val_loss: 0.1944
# Epoch 43/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1797 - val_loss: 0.1909
# Epoch 44/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.1775 - val_loss: 0.1882
# Epoch 45/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1735 - val_loss: 0.1859
# Epoch 46/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1721 - val_loss: 0.1833
# Epoch 47/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1688 - val_loss: 0.1809
# Epoch 48/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1645 - val_loss: 0.1789
# Epoch 49/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1653 - val_loss: 0.1773
# Epoch 50/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.1608 - val_loss: 0.1761
# Epoch 51/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1629 - val_loss: 0.1748
# Epoch 52/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.1612 - val_loss: 0.1737
# Epoch 53/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1584 - val_loss: 0.1725
# Epoch 54/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.1568 - val_loss: 0.1715
# Epoch 55/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.1593 - val_loss: 0.1708
# Epoch 56/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1537 - val_loss: 0.1698
# Epoch 57/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1549 - val_loss: 0.1688
# Epoch 58/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1490 - val_loss: 0.1675
# Epoch 59/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.1498 - val_loss: 0.1667
# Epoch 60/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.1501 - val_loss: 0.1656
# Epoch 61/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1490 - val_loss: 0.1644
# Epoch 62/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1484 - val_loss: 0.1638
# Epoch 63/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.1470 - val_loss: 0.1631
# Epoch 64/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1450 - val_loss: 0.1619
# Epoch 65/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1456 - val_loss: 0.1610
# Epoch 66/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1443 - val_loss: 0.1602
# Epoch 67/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1439 - val_loss: 0.1597
# Epoch 68/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1424 - val_loss: 0.1585
# Epoch 69/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1402 - val_loss: 0.1581
# Epoch 70/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.1400 - val_loss: 0.1572
# Epoch 71/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.1397 - val_loss: 0.1560
# Epoch 72/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.1372 - val_loss: 0.1551
# Epoch 73/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1377 - val_loss: 0.1540
# Epoch 74/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1370 - val_loss: 0.1529
# Epoch 75/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.1351 - val_loss: 0.1519
# Epoch 76/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.1354 - val_loss: 0.1511
# Epoch 77/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1308 - val_loss: 0.1500
# Epoch 78/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.1326 - val_loss: 0.1493
# Epoch 79/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1297 - val_loss: 0.1484
# Epoch 80/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1292 - val_loss: 0.1474
# Epoch 81/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1273 - val_loss: 0.1464
# Epoch 82/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1261 - val_loss: 0.1453
# Epoch 83/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1255 - val_loss: 0.1445
# Epoch 84/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1249 - val_loss: 0.1441
# Epoch 85/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.1268 - val_loss: 0.1429
# Epoch 86/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1248 - val_loss: 0.1418
# Epoch 87/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1242 - val_loss: 0.1411
# Epoch 88/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1217 - val_loss: 0.1404
# Epoch 89/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1216 - val_loss: 0.1396
# Epoch 90/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1198 - val_loss: 0.1385
# Epoch 91/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.1191 - val_loss: 0.1377
# Epoch 92/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1199 - val_loss: 0.1370
# Epoch 93/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1186 - val_loss: 0.1364
# Epoch 94/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1173 - val_loss: 0.1350
# Epoch 95/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1146 - val_loss: 0.1347
# Epoch 96/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1143 - val_loss: 0.1332
# Epoch 97/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1154 - val_loss: 0.1325
# Epoch 98/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1112 - val_loss: 0.1314
# Epoch 99/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1110 - val_loss: 0.1306
# Epoch 100/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.1093 - val_loss: 0.1296
# Epoch 101/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.1086 - val_loss: 0.1289
# Epoch 102/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.1100 - val_loss: 0.1281
# Epoch 103/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1087 - val_loss: 0.1272
# Epoch 104/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1074 - val_loss: 0.1265
# Epoch 105/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1078 - val_loss: 0.1259
# Epoch 106/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1066 - val_loss: 0.1247
# Epoch 107/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1057 - val_loss: 0.1240
# Epoch 108/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.1034 - val_loss: 0.1234
# Epoch 109/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.1049 - val_loss: 0.1226
# Epoch 110/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.1044 - val_loss: 0.1216
# Epoch 111/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1043 - val_loss: 0.1212
# Epoch 112/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1013 - val_loss: 0.1203
# Epoch 113/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1021 - val_loss: 0.1192
# Epoch 114/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1012 - val_loss: 0.1188
# Epoch 115/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.1003 - val_loss: 0.1180
# Epoch 116/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1002 - val_loss: 0.1170
# Epoch 117/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0978 - val_loss: 0.1162
# Epoch 118/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0973 - val_loss: 0.1156
# Epoch 119/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0968 - val_loss: 0.1150
# Epoch 120/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0960 - val_loss: 0.1140
# Epoch 121/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0946 - val_loss: 0.1136
# Epoch 122/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0960 - val_loss: 0.1130
# Epoch 123/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0935 - val_loss: 0.1125
# Epoch 124/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0922 - val_loss: 0.1123
# Epoch 125/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0934 - val_loss: 0.1112
# Epoch 126/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0915 - val_loss: 0.1105
# Epoch 127/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0893 - val_loss: 0.1100
# Epoch 128/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0895 - val_loss: 0.1094
# Epoch 129/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0906 - val_loss: 0.1089
# Epoch 130/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0892 - val_loss: 0.1080
# Epoch 131/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0880 - val_loss: 0.1076
# Epoch 132/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0879 - val_loss: 0.1067
# Epoch 133/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0866 - val_loss: 0.1062
# Epoch 134/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0856 - val_loss: 0.1056
# Epoch 135/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0857 - val_loss: 0.1048
# Epoch 136/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0845 - val_loss: 0.1041
# Epoch 137/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0828 - val_loss: 0.1034
# Epoch 138/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0843 - val_loss: 0.1029
# Epoch 139/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0828 - val_loss: 0.1018
# Epoch 140/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0821 - val_loss: 0.1011
# Epoch 141/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0830 - val_loss: 0.1006
# Epoch 142/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0812 - val_loss: 0.0997
# Epoch 143/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0812 - val_loss: 0.0998
# Epoch 144/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0817 - val_loss: 0.0987
# Epoch 145/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0794 - val_loss: 0.0980
# Epoch 146/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0799 - val_loss: 0.0977
# Epoch 147/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0790 - val_loss: 0.0966
# Epoch 148/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0786 - val_loss: 0.0970
# Epoch 149/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0765 - val_loss: 0.0956
# Epoch 150/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0766 - val_loss: 0.0954
# Epoch 151/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0772 - val_loss: 0.0947
# Epoch 152/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0761 - val_loss: 0.0942
# Epoch 153/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0753 - val_loss: 0.0940
# Epoch 154/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0744 - val_loss: 0.0932
# Epoch 155/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0743 - val_loss: 0.0928
# Epoch 156/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0742 - val_loss: 0.0921
# Epoch 157/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0734 - val_loss: 0.0920
# Epoch 158/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0732 - val_loss: 0.0914
# Epoch 159/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0731 - val_loss: 0.0908
# Epoch 160/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0705 - val_loss: 0.0905
# Epoch 161/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0718 - val_loss: 0.0898
# Epoch 162/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0705 - val_loss: 0.0893
# Epoch 163/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0701 - val_loss: 0.0887
# Epoch 164/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0706 - val_loss: 0.0885
# Epoch 165/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0703 - val_loss: 0.0885
# Epoch 166/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0693 - val_loss: 0.0878
# Epoch 167/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0689 - val_loss: 0.0879
# Epoch 168/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0691 - val_loss: 0.0870
# Epoch 169/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0686 - val_loss: 0.0866
# Epoch 170/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0679 - val_loss: 0.0859
# Epoch 171/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0678 - val_loss: 0.0859
# Epoch 172/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0667 - val_loss: 0.0854
# Epoch 173/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0659 - val_loss: 0.0846
# Epoch 174/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0648 - val_loss: 0.0843
# Epoch 175/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0653 - val_loss: 0.0846
# Epoch 176/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0645 - val_loss: 0.0836
# Epoch 177/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0644 - val_loss: 0.0833
# Epoch 178/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0630 - val_loss: 0.0832
# Epoch 179/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0642 - val_loss: 0.0825
# Epoch 180/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0628 - val_loss: 0.0825
# Epoch 181/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0649 - val_loss: 0.0820
# Epoch 182/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0628 - val_loss: 0.0814
# Epoch 183/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0612 - val_loss: 0.0806
# Epoch 184/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0614 - val_loss: 0.0809
# Epoch 185/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0623 - val_loss: 0.0798
# Epoch 186/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0606 - val_loss: 0.0794
# Epoch 187/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0608 - val_loss: 0.0792
# Epoch 188/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0593 - val_loss: 0.0791
# Epoch 189/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0601 - val_loss: 0.0780
# Epoch 190/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0590 - val_loss: 0.0780
# Epoch 191/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0586 - val_loss: 0.0771
# Epoch 192/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0581 - val_loss: 0.0769
# Epoch 193/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0576 - val_loss: 0.0766
# Epoch 194/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0580 - val_loss: 0.0771
# Epoch 195/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0580 - val_loss: 0.0756
# Epoch 196/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0562 - val_loss: 0.0751
# Epoch 197/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0564 - val_loss: 0.0746
# Epoch 198/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0570 - val_loss: 0.0750
# Epoch 199/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0551 - val_loss: 0.0737
# Epoch 200/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0552 - val_loss: 0.0731
# Restoring model weights from the end of the best epoch: 200.

# %%
# Create figure with specified size
plt.figure(figsize=(12, 8))

# Plot training and validation loss
plt.plot(history.history['loss'], 'b-', label='Training loss', linewidth=2)
plt.plot(history.history['val_loss'], 'r--', label='Validation loss', linewidth=2)

# Customize the plot
plt.xlabel('Epoch', fontsize=12)
plt.ylabel('Loss (MAE)', fontsize=12)
plt.title('Training and Validation Loss Over Time - LSTM Autoencoder', fontsize=14)
plt.grid(True, linestyle='--', alpha=0.7)

# Add legend with larger font
plt.legend(fontsize=12)

# Adjust y-axis to start from 0
plt.ylim(bottom=0)

# Add minor grid lines for finer scale
plt.minorticks_on()
plt.grid(True, which='minor', linestyle=':', alpha=0.4)

# Make axis labels more readable
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Adjust layout to prevent label cutoff
plt.tight_layout()

plt.show()

# %%
from keras import ops
model.save('../../../models/lstm_autoencoder_best.keras')

# %%
load_model = tf.keras.models.load_model('../../../models/lstm_autoencoder_best.keras')

# %%
# Calculate reconstruction errors for test data
train_reconstructions_normal = load_model.predict(normal_train_data_scaled_lstm)
train_loss_normal = tf.keras.losses.mae(train_reconstructions_normal, normal_train_data_scaled_lstm)
# Flatten the loss array and convert to numpy for plotting
train_loss_normal_flat = train_loss_normal.numpy().flatten()
# Plot histogram
plt.figure(figsize=(10, 6))
plt.hist(train_loss_normal_flat, bins=50)
plt.xlabel("Reconstruction Error (Normal Training Data)")
plt.ylabel("Number of Examples")
plt.title("Distribution of Reconstruction Errors")
plt.show()
# Out:
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
# Calculate reconstruction errors for abnormal data
train_reconstructions_abnormal = load_model.predict(abnormal_train_data_scaled_lstm)
train_loss_abnormal = tf.keras.losses.mae(train_reconstructions_abnormal, abnormal_train_data_scaled_lstm)
# Flatten the loss array and convert to numpy for plotting
train_loss_abnormal_flat = train_loss_abnormal.numpy().flatten()

# Plot histogram
plt.figure(figsize=(10, 6))
plt.hist(train_loss_abnormal_flat, bins=50, color='orange', alpha=0.7)
plt.xlabel("Reconstruction Error (Abnormal Training Data)")
plt.ylabel("Number of Examples")
plt.title("Distribution of Reconstruction Errors - Abnormal Data")
plt.show()

# Calculate and display minimum reconstruction error for abnormal data
min_error = np.min(train_loss_abnormal_flat)
print(f"\nMinimum reconstruction error for abnormal data: {min_error:.4f}")
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Minimum reconstruction error for abnormal data: 0.2007

# %%
# Create combined histogram plot
plt.figure(figsize=(10, 6))
plt.hist(train_loss_normal_flat, bins=50, alpha=0.7, label='Normal', color='blue')
plt.hist(train_loss_abnormal_flat, bins=50, alpha=0.7, label='Abnormal', color='red')
plt.ylim(0, 60)
plt.xlabel('Reconstruction Error (MAE)')
plt.ylabel('Number of Examples')
plt.title('Distribution of Reconstruction Errors - LSTM Autoencoder')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# %%
# Calculate thresholds
low_threshold = 0.2 # all anomalies are caught
high_threshold = np.percentile(train_loss_normal, 99.99)  # Loose threshold (99th percentile)
print("Low threshold: ", low_threshold)
print("High threshold: ", high_threshold)
# Out:
# Low threshold:  0.2
# High threshold:  0.6914749

# %%
# Function to calculate precision, recall, and F1 score
def calculate_metrics(threshold, normal_losses, abnormal_losses):
    # Convert TensorFlow tensors to NumPy arrays
    normal_losses = normal_losses.numpy()
    abnormal_losses = abnormal_losses.numpy()
    
    predictions_normal = (normal_losses > threshold).astype(int)
    predictions_abnormal = (abnormal_losses > threshold).astype(int)
    
    tp = np.sum(predictions_abnormal == 1)
    fp = np.sum(predictions_normal == 1)
    fn = np.sum(predictions_abnormal == 0)
    
    precision = tp / (tp + fp) if (tp + fp) > 0 else 0
    recall = tp / (tp + fn) if (tp + fn) > 0 else 0
    f1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0
    
    return precision, recall, f1

# %%
# Generate threshold values based on the range of reconstruction errors
min_loss = min(np.min(train_loss_normal_flat), np.min(train_loss_abnormal_flat))
max_loss = max(np.max(train_loss_normal_flat), np.max(train_loss_abnormal_flat))
thresholds = np.linspace(min_loss, max_loss, 100)

# Calculate metrics for each threshold
precisions = []
recalls = []
f1_scores = []

for threshold in thresholds:
    precision, recall, f1 = calculate_metrics(threshold, train_loss_normal, train_loss_abnormal)
    precisions.append(precision)
    recalls.append(recall)
    f1_scores.append(f1)

# Find the best F1 score and its threshold
best_idx = np.argmax(f1_scores)
best_threshold = thresholds[best_idx]
best_f1 = f1_scores[best_idx]

# %%
# Plot metrics vs threshold
plt.figure(figsize=(12, 6))
plt.plot(thresholds, precisions, 'b-', label='Precision', alpha=0.7)
plt.plot(thresholds, recalls, 'g-', label='Recall', alpha=0.7)
plt.plot(thresholds, f1_scores, 'r-', label='F1 Score', linewidth=2)

# Mark the best F1 score
plt.plot(best_threshold, best_f1, 'r*', markersize=15, 
         label=f'Best F1: {best_f1:.3f} at {best_threshold:.3f}')

# Customize the plot
plt.xlabel('Threshold Value')
plt.ylabel('Score')
plt.title('Precision, Recall, and F1 Score vs Threshold - LSTM Autoencoder')
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()

# Print the optimal threshold and metrics
print(f"\nOptimal threshold (best F1 score): {best_threshold:.4f}")
print(f"Best F1 score: {best_f1:.4f}")
print(f"Precision at best F1: {precisions[best_idx]:.4f}")
print(f"Recall at best F1: {recalls[best_idx]:.4f}")
# Out:
# Optimal threshold (best F1 score): 0.3767
# Best F1 score: 0.9619
# Precision at best F1: 0.9601
# Recall at best F1: 0.9636
