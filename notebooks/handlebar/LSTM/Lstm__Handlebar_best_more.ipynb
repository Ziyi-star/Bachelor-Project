# %% [markdown]
# <a href="https://colab.research.google.com/github/Ziyi-star/Bachelor-Project/blob/main/notebooks/handlebar/LSTM/Lstm__Handlebar_best.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# For Vscode
import numpy as np
import pandas as pd
from tensorflow import keras
from tensorflow.keras import layers
from datetime import datetime
from matplotlib import pyplot as plt
from matplotlib import dates as md
from sklearn.model_selection import train_test_split    #model selection and scaling data
from sklearn.preprocessing import StandardScaler
import tensorflow as tf #building model
RANDOM_SEED = 42

import sys
sys.path.append('../../../')   # Add parent directory to Python path
from utils.Plots import *

df = pd.read_csv('../../../data/handlebar/processed_segments_overlap_50_more.csv')
# 0 for normal, 1 for abnormal
df['curb_scene'].value_counts()
#df.drop('Unnamed: 0', axis=1, inplace=True)
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 18
#      15 sys.path.append('../../../')   # Add parent directory to Python path
#      16 from utils.Plots import *
# ---> 18 df = pd.read_csv('../../../data/handlebar/processed_segments_overlap_50_more.csv.csv')
#      19 # 0 for normal, 1 for abnormal
#      20 df['curb_scene'].value_counts()
#
# File c:\Users\liuzi\miniconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\liuzi\miniconda3\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File c:\Users\liuzi\miniconda3\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\liuzi\miniconda3\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File c:\Users\liuzi\miniconda3\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../../data/handlebar/processed_segments_overlap_50_more.csv.csv'

# %%
# For Colab
import numpy as np
import pandas as pd
from tensorflow import keras
from tensorflow.keras import layers
from datetime import datetime
from matplotlib import pyplot as plt
from matplotlib import dates as md
from sklearn.model_selection import train_test_split    #model selection and scaling data
from sklearn.preprocessing import StandardScaler
import tensorflow as tf #building model
RANDOM_SEED = 42


import os
from google.colab import drive
drive.mount('/content/drive')
df = pd.read_csv('/content/drive/MyDrive/Project/data/processed_segments_overlap_50_more.csv')
# # 0 for normal, 1 for abnormal
df['curb_scene'].value_counts()
df.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#    Unnamed: 0  curb_scene   Acc-Z_1   Acc-Z_2   Acc-Z_3   Acc-Z_4   Acc-Z_5  \
# 0           0         0.0  8.762772  8.753204  8.762772  8.781937  8.753204
# 1           0         0.0  8.762772  8.762772  8.748413  8.767563  8.729263
# 2           0         0.0  8.781937  8.796295  8.772354  8.772354  8.772354
# 3           0         0.0  8.781937  8.753204  8.801086  8.753204  8.829819
# 4           0         0.0  8.757996  8.762772  8.777145  8.767563  8.786728
#
#     Acc-Z_6   Acc-Z_7   Acc-Z_8  ...  Acc-Z_91  Acc-Z_92  Acc-Z_93  Acc-Z_94  \
# 0  8.748413  8.738831  8.748413  ...  8.786728  8.801086  8.820236  8.786728
# 1  8.695740  8.724472  8.767563  ...  8.753204  8.772354  8.786728  8.781937
# 2  8.786728  8.781937  8.801086  ...  8.777145  8.753204  8.767563  8.762772
# 3  8.753204  8.786728  8.815445  ...  8.805878  8.796295  8.781937  8.801086
# 4  8.777145  8.753204  8.757996  ...  8.757996  8.757996  8.772354  8.767563
#
#    Acc-Z_95  Acc-Z_96  Acc-Z_97  Acc-Z_98  Acc-Z_99  Acc-Z_100
# 0  8.777145  8.772354  8.781937  8.801086  8.781937   8.753204
# 1  8.786728  8.777145  8.738831  8.820236  8.738831   8.757996
# 2  8.762772  8.753204  8.748413  8.762772  8.772354   8.767563
# 3  8.810669  8.796295  8.805878  8.791504  8.791504   8.772354
# 4  8.757996  8.743622  8.777145  8.743622  8.786728   8.796295
#
# [5 rows x 102 columns]

# %%
#df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
# Suppose df is your DataFrame, and df['curb_scene'] is your label column
train_data, test_data, train_labels, test_labels = train_test_split(df, df['curb_scene'],
                                                                    test_size=0.2,
                                                                    random_state=RANDOM_SEED)

# %%
#scaling data, because neural network works better with scaled data
scaler = StandardScaler()
data_scaled = scaler.fit(train_data.iloc[:, 3:])
#transform data
train_data_scaled = scaler.transform(train_data.iloc[:, 3:])
test_data_scaled = scaler.transform(test_data.iloc[:, 3:])
train_data_scaled.shape
# Out:
# (2984, 100)

# %%
# Convert the scaled data back to DataFrames for further processing
# takes all column names from the original DataFrame starting from index 3
train_data_scaled_df = pd.DataFrame(train_data_scaled, columns=train_data.columns[3:])
test_data_scaled_df = pd.DataFrame(test_data_scaled, columns=test_data.columns[3:])
# Add the 'curb_scene', 'start_time', and 'end_time' columns back to the scaled DataFrames
train_data_scaled_df['curb_scene'] = train_data['curb_scene'].values
test_data_scaled_df['curb_scene'] = test_data['curb_scene'].values
train_data_scaled_df.head()
# Out:
#     Acc-Z_1   Acc-Z_2   Acc-Z_3   Acc-Z_4   Acc-Z_5   Acc-Z_6   Acc-Z_7  \
# 0 -0.043399 -0.036445 -0.039909 -0.060094 -0.050310 -0.047696 -0.075391
# 1  1.732833  0.861269 -0.066900 -1.345973 -0.894126  0.209820  0.934705
# 2  1.108598 -0.307952 -1.216212 -1.146256  0.185394  1.187373  0.592034
# 3 -0.553325 -0.653575 -1.007376 -1.028728 -0.073208  0.570197  0.683861
# 4  0.970780  1.017063  0.127729 -0.398848 -0.465148 -0.729610 -1.568511
#
#     Acc-Z_8   Acc-Z_9  Acc-Z_10  ...  Acc-Z_92  Acc-Z_93  Acc-Z_94  Acc-Z_95  \
# 0 -0.089531 -0.090752 -0.076505  ... -0.043150 -0.071323 -0.096998 -0.097019
# 1  0.829993 -0.302878 -0.544242  ...  0.655119 -0.304608 -0.794407 -1.651467
# 2 -1.013123 -0.958307  0.582645  ... -0.685252 -0.784423  0.974519  1.458073
# 3  0.283433 -0.743554  0.084684  ...  0.607887 -0.015207 -0.946822 -0.043461
# 4 -1.432877 -0.073019  0.897828  ... -0.536533  0.011905 -0.465826 -0.511925
#
#    Acc-Z_96  Acc-Z_97  Acc-Z_98  Acc-Z_99  Acc-Z_100  curb_scene
# 0 -0.058825 -0.062461 -0.066930 -0.065874  -0.066939         0.0
# 1 -1.752088 -0.370351 -0.366041  1.040036   1.820544         1.0
# 2  0.009070 -1.326325 -0.443189  0.728941   1.383342         0.0
# 3 -0.298542 -0.262453 -0.822154 -0.065264   0.862935         0.0
# 4 -0.461355 -0.283758 -0.314610  0.056735  -0.128249         0.0
#
# [5 rows x 101 columns]

# %%
# Filter and slice the data
normal_train_data_scaled = train_data_scaled_df[train_data_scaled_df['curb_scene'] == 0.0].iloc[:, :-1]
abnormal_train_data_scaled = train_data_scaled_df[train_data_scaled_df['curb_scene'] == 1.0].iloc[:, :-1]
normal_test_data_scaled = test_data_scaled_df[test_data_scaled_df['curb_scene'] == 0.0].iloc[:, :-1]
abnormal_test_data_scaled = test_data_scaled_df[test_data_scaled_df['curb_scene'] == 1.0].iloc[:, :-1]

# %%
# Cast to float32
normal_train_data_scaled = normal_train_data_scaled.astype("float32")
abnormal_train_data_scaled = abnormal_train_data_scaled.astype("float32")
normal_test_data_scaled = normal_test_data_scaled.astype("float32")
abnormal_test_data_scaled = abnormal_test_data_scaled.astype("float32")

# %%
# Reshape the data for LSTM input((samples, timesteps, features))
normal_train_data_scaled_lstm = np.expand_dims(normal_train_data_scaled, axis=1)
normal_test_data_scaled_lstm = np.expand_dims(normal_test_data_scaled, axis=1)
abnormal_test_data_scaled_lstm = np.expand_dims(abnormal_test_data_scaled, axis=1)
normal_train_data_scaled_lstm.shape, normal_test_data_scaled_lstm.shape, abnormal_test_data_scaled_lstm.shape
# Out:
# ((2830, 1, 100), (711, 1, 100), (35, 1, 100))

# %%
from keras.models import Sequential
from keras.layers import LSTM, Input, Dropout
from keras.layers import Dense
from keras.layers import RepeatVector
from keras.layers import TimeDistributed
from keras.models import Model

model = Sequential()
# Encoder
model.add(Input(shape=(normal_train_data_scaled_lstm.shape[1], normal_train_data_scaled_lstm.shape[2])))
model.add(LSTM(224, activation='tanh', return_sequences=True))
model.add(LSTM(224, activation='tanh', return_sequences=True))

#decoder
model.add(LSTM(224, activation='tanh', return_sequences=True))
model.add(LSTM(224, activation='tanh', return_sequences=True))
model.add(TimeDistributed(Dense(normal_train_data_scaled_lstm.shape[2])))
model.compile(optimizer='adam', loss='mae')
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 1, 224)         │       291,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 1, 224)         │       402,304 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 1, 224)         │       402,304 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_3 (LSTM)                   │ (None, 1, 224)         │       402,304 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed                │ (None, 1, 100)         │        22,500 │
# │ (TimeDistributed)               │                        │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,520,612 (5.80 MB)
#  Trainable params: 1,520,612 (5.80 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# define early stopping to prevent overfit
early_stopping = keras.callbacks.EarlyStopping(monitor="val_loss",
                                               patience=10,
                                               mode="min",
                                               verbose=1,
                                               restore_best_weights=True)

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=0.00044)
model.compile(optimizer=optimizer, loss='mae')

# %%
# fit model
history = model.fit(
    normal_train_data_scaled_lstm, normal_train_data_scaled_lstm,
    epochs=200,
    batch_size=128,
    validation_split=0.3,
    callbacks=[early_stopping],
    shuffle=True,
    verbose=1)
# Out:
# Epoch 1/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - loss: 0.4310 - val_loss: 0.4354
# Epoch 2/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.4329 - val_loss: 0.4333
# Epoch 3/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.4284 - val_loss: 0.4233
# Epoch 4/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.4179 - val_loss: 0.4104
# Epoch 5/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.4048 - val_loss: 0.3964
# Epoch 6/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.3855 - val_loss: 0.3856
# Epoch 7/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.3840 - val_loss: 0.3814
# Epoch 8/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.3799 - val_loss: 0.3745
# Epoch 9/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.3744 - val_loss: 0.3653
# Epoch 10/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.3640 - val_loss: 0.3605
# Epoch 11/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.3581 - val_loss: 0.3533
# Epoch 12/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.3495 - val_loss: 0.3464
# Epoch 13/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.3505 - val_loss: 0.3440
# Epoch 14/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.3419 - val_loss: 0.3428
# Epoch 15/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.3411 - val_loss: 0.3418
# Epoch 16/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.3354 - val_loss: 0.3408
# Epoch 17/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.3362 - val_loss: 0.3391
# Epoch 18/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.3360 - val_loss: 0.3350
# Epoch 19/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.3376 - val_loss: 0.3319
# Epoch 20/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.3279 - val_loss: 0.3306
# Epoch 21/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.3217 - val_loss: 0.3293
# Epoch 22/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.3307 - val_loss: 0.3267
# Epoch 23/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.3186 - val_loss: 0.3218
# Epoch 24/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.3228 - val_loss: 0.3200
# Epoch 25/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.3064 - val_loss: 0.3191
# Epoch 26/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.3104 - val_loss: 0.3181
# Epoch 27/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.3121 - val_loss: 0.3166
# Epoch 28/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.3134 - val_loss: 0.3139
# Epoch 29/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.3049 - val_loss: 0.3103
# Epoch 30/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.3001 - val_loss: 0.3074
# Epoch 31/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2999 - val_loss: 0.3047
# Epoch 32/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2973 - val_loss: 0.3037
# Epoch 33/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2968 - val_loss: 0.3031
# Epoch 34/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2981 - val_loss: 0.3027
# Epoch 35/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2976 - val_loss: 0.3025
# Epoch 36/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2979 - val_loss: 0.3019
# Epoch 37/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2922 - val_loss: 0.3014
# Epoch 38/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2905 - val_loss: 0.3004
# Epoch 39/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2883 - val_loss: 0.2988
# Epoch 40/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2888 - val_loss: 0.2971
# Epoch 41/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2834 - val_loss: 0.2962
# Epoch 42/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.2829 - val_loss: 0.2952
# Epoch 43/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2834 - val_loss: 0.2937
# Epoch 44/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.2845 - val_loss: 0.2916
# Epoch 45/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2791 - val_loss: 0.2897
# Epoch 46/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2824 - val_loss: 0.2880
# Epoch 47/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2704 - val_loss: 0.2862
# Epoch 48/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2716 - val_loss: 0.2848
# Epoch 49/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2678 - val_loss: 0.2832
# Epoch 50/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2682 - val_loss: 0.2821
# Epoch 51/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.2673 - val_loss: 0.2810
# Epoch 52/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.2697 - val_loss: 0.2798
# Epoch 53/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2569 - val_loss: 0.2783
# Epoch 54/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2614 - val_loss: 0.2770
# Epoch 55/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.2635 - val_loss: 0.2759
# Epoch 56/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2572 - val_loss: 0.2747
# Epoch 57/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2590 - val_loss: 0.2729
# Epoch 58/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2507 - val_loss: 0.2708
# Epoch 59/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2555 - val_loss: 0.2691
# Epoch 60/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2481 - val_loss: 0.2673
# Epoch 61/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2486 - val_loss: 0.2656
# Epoch 62/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2422 - val_loss: 0.2639
# Epoch 63/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2421 - val_loss: 0.2622
# Epoch 64/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2410 - val_loss: 0.2601
# Epoch 65/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.2391 - val_loss: 0.2583
# Epoch 66/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2314 - val_loss: 0.2562
# Epoch 67/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2288 - val_loss: 0.2543
# Epoch 68/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2236 - val_loss: 0.2525
# Epoch 69/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2278 - val_loss: 0.2506
# Epoch 70/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2237 - val_loss: 0.2489
# Epoch 71/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2204 - val_loss: 0.2469
# Epoch 72/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.2195 - val_loss: 0.2451
# Epoch 73/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2177 - val_loss: 0.2434
# Epoch 74/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2172 - val_loss: 0.2415
# Epoch 75/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2145 - val_loss: 0.2397
# Epoch 76/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2108 - val_loss: 0.2378
# Epoch 77/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2103 - val_loss: 0.2357
# Epoch 78/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2041 - val_loss: 0.2339
# Epoch 79/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2049 - val_loss: 0.2320
# Epoch 80/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.1994 - val_loss: 0.2296
# Epoch 81/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.1988 - val_loss: 0.2275
# Epoch 82/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.1963 - val_loss: 0.2251
# Epoch 83/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.1942 - val_loss: 0.2225
# Epoch 84/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1889 - val_loss: 0.2200
# Epoch 85/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1937 - val_loss: 0.2178
# Epoch 86/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.1870 - val_loss: 0.2157
# Epoch 87/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.1849 - val_loss: 0.2141
# Epoch 88/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.1844 - val_loss: 0.2123
# Epoch 89/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1800 - val_loss: 0.2107
# Epoch 90/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.1816 - val_loss: 0.2089
# Epoch 91/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.1799 - val_loss: 0.2069
# Epoch 92/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1757 - val_loss: 0.2050
# Epoch 93/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1759 - val_loss: 0.2029
# Epoch 94/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.1702 - val_loss: 0.2010
# Epoch 95/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.1686 - val_loss: 0.1991
# Epoch 96/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1683 - val_loss: 0.1975
# Epoch 97/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.1642 - val_loss: 0.1957
# Epoch 98/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.1623 - val_loss: 0.1944
# Epoch 99/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.1616 - val_loss: 0.1930
# Epoch 100/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.1601 - val_loss: 0.1919
# Epoch 101/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.1596 - val_loss: 0.1906
# Epoch 102/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1558 - val_loss: 0.1898
# Epoch 103/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.1589 - val_loss: 0.1890
# Epoch 104/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1594 - val_loss: 0.1883
# Epoch 105/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.1521 - val_loss: 0.1877
# Epoch 106/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1533 - val_loss: 0.1871
# Epoch 107/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1521 - val_loss: 0.1862
# Epoch 108/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1510 - val_loss: 0.1856
# Epoch 109/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1520 - val_loss: 0.1851
# Epoch 110/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.1479 - val_loss: 0.1842
# Epoch 111/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1469 - val_loss: 0.1835
# Epoch 112/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.1466 - val_loss: 0.1829
# Epoch 113/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1462 - val_loss: 0.1822
# Epoch 114/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.1427 - val_loss: 0.1815
# Epoch 115/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.1429 - val_loss: 0.1808
# Epoch 116/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1450 - val_loss: 0.1799
# Epoch 117/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1390 - val_loss: 0.1797
# Epoch 118/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1398 - val_loss: 0.1792
# Epoch 119/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1403 - val_loss: 0.1784
# Epoch 120/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1380 - val_loss: 0.1779
# Epoch 121/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1388 - val_loss: 0.1774
# Epoch 122/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.1378 - val_loss: 0.1771
# Epoch 123/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.1385 - val_loss: 0.1766
# Epoch 124/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1365 - val_loss: 0.1761
# Epoch 125/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1354 - val_loss: 0.1756
# Epoch 126/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1347 - val_loss: 0.1755
# Epoch 127/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1368 - val_loss: 0.1751
# Epoch 128/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1334 - val_loss: 0.1747
# Epoch 129/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1340 - val_loss: 0.1743
# Epoch 130/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.1332 - val_loss: 0.1740
# Epoch 131/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1307 - val_loss: 0.1735
# Epoch 132/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.1299 - val_loss: 0.1733
# Epoch 133/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1283 - val_loss: 0.1733
# Epoch 134/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.1308 - val_loss: 0.1728
# Epoch 135/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1283 - val_loss: 0.1724
# Epoch 136/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.1287 - val_loss: 0.1720
# Epoch 137/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.1277 - val_loss: 0.1718
# Epoch 138/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.1267 - val_loss: 0.1714
# Epoch 139/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1256 - val_loss: 0.1711
# Epoch 140/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1252 - val_loss: 0.1707
# Epoch 141/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1250 - val_loss: 0.1704
# Epoch 142/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1259 - val_loss: 0.1701
# Epoch 143/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.1256 - val_loss: 0.1697
# Epoch 144/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.1233 - val_loss: 0.1697
# Epoch 145/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.1252 - val_loss: 0.1692
# Epoch 146/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.1229 - val_loss: 0.1688
# Epoch 147/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1206 - val_loss: 0.1683
# Epoch 148/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.1226 - val_loss: 0.1683
# Epoch 149/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.1198 - val_loss: 0.1678
# Epoch 150/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1192 - val_loss: 0.1675
# Epoch 151/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.1191 - val_loss: 0.1672
# Epoch 152/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1189 - val_loss: 0.1668
# Epoch 153/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1169 - val_loss: 0.1665
# Epoch 154/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.1181 - val_loss: 0.1660
# Epoch 155/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1170 - val_loss: 0.1657
# Epoch 156/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.1165 - val_loss: 0.1654
# Epoch 157/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.1169 - val_loss: 0.1649
# Epoch 158/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.1148 - val_loss: 0.1645
# Epoch 159/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.1139 - val_loss: 0.1643
# Epoch 160/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.1166 - val_loss: 0.1638
# Epoch 161/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.1136 - val_loss: 0.1636
# Epoch 162/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1132 - val_loss: 0.1632
# Epoch 163/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1135 - val_loss: 0.1629
# Epoch 164/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.1115 - val_loss: 0.1625
# Epoch 165/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1117 - val_loss: 0.1620
# Epoch 166/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1124 - val_loss: 0.1618
# Epoch 167/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1108 - val_loss: 0.1612
# Epoch 168/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.1117 - val_loss: 0.1608
# Epoch 169/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1089 - val_loss: 0.1605
# Epoch 170/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1088 - val_loss: 0.1601
# Epoch 171/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.1079 - val_loss: 0.1597
# Epoch 172/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1066 - val_loss: 0.1592
# Epoch 173/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1083 - val_loss: 0.1589
# Epoch 174/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.1074 - val_loss: 0.1585
# Epoch 175/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.1060 - val_loss: 0.1580
# Epoch 176/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1047 - val_loss: 0.1578
# Epoch 177/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1049 - val_loss: 0.1570
# Epoch 178/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.1041 - val_loss: 0.1567
# Epoch 179/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.1033 - val_loss: 0.1562
# Epoch 180/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.1032 - val_loss: 0.1558
# Epoch 181/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1028 - val_loss: 0.1553
# Epoch 182/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.1020 - val_loss: 0.1549
# Epoch 183/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1006 - val_loss: 0.1545
# Epoch 184/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0997 - val_loss: 0.1539
# Epoch 185/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0990 - val_loss: 0.1536
# Epoch 186/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0980 - val_loss: 0.1529
# Epoch 187/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.1001 - val_loss: 0.1524
# Epoch 188/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0979 - val_loss: 0.1519
# Epoch 189/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0977 - val_loss: 0.1515
# Epoch 190/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0992 - val_loss: 0.1509
# Epoch 191/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0974 - val_loss: 0.1506
# Epoch 192/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0967 - val_loss: 0.1501
# Epoch 193/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0936 - val_loss: 0.1497
# Epoch 194/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0960 - val_loss: 0.1492
# Epoch 195/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0941 - val_loss: 0.1488
# Epoch 196/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0947 - val_loss: 0.1482
# Epoch 197/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0936 - val_loss: 0.1477
# Epoch 198/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0940 - val_loss: 0.1471
# Epoch 199/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0916 - val_loss: 0.1468
# Epoch 200/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0919 - val_loss: 0.1462
# Restoring model weights from the end of the best epoch: 200.

# %%
plt.plot(history.history['loss'], label='Training loss')
plt.plot(history.history['val_loss'], label='Validation loss')
plt.legend()

# %%
load_model = tf.keras.models.load_model('../../../models/lstm_autoencoder_handlebar_best.keras')
# Out:
# c:\Users\liuzi\miniconda3\Lib\site-packages\keras\src\saving\saving_lib.py:757: UserWarning: Skipping variable loading for optimizer 'rmsprop', because it has 16 variables whereas the saved optimizer has 30 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
